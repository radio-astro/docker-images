# %%
import aplpy

# %%
ls /data/example
# Out:
# 2MASS_h.fits  2MASS_j.fits  2MASS_k.fits  mips_24micron.fits

# %%
gc = aplpy.FITSFigure('/data/example/2MASS_h.fits')
gc.show_colorscale(cmap='gist_heat')
gc.show_contour('/data/example/mips_24micron.fits', colors='white')
# Out:
# INFO:astropy:Auto-setting vmin to  4.195e+02
# INFO:astropy:Auto-setting vmax to  1.165e+03
# INFO: Auto-setting vmin to  4.195e+02 [aplpy.aplpy]
# INFO: Auto-setting vmax to  1.165e+03 [aplpy.aplpy]
